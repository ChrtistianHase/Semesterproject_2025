# %%
import numpy as np
import polartoolkit as ptk
import verde as vd
import numpy as np
import os
os.environ["POLARTOOLKIT_HEMISPHERE"] = "south"

# %%
region = ptk.regions.getz_ice_shelf

# Use source ID from Bedmachine to identify coordinates of known bed topography
# get bedmachine data id grid
number_to_source = {
    0: "no_data",
    1: "rema",
    2: "radar",
    7: "seismic",
    10: "multibeam",
}
dataid = ptk.fetch.bedmachine(layer="dataid").compute()

# drop grid cells of "no_data"
dataid_ds = dataid.where(dataid != 0, drop=True)

# turn into dataframe
dataid_df = (
    vd.grid_to_table(dataid_ds)
    .dropna()
    .rename(columns={"x": "easting", "y": "northing"})
)
dataid_df["source"] = dataid_df.dataid.map(number_to_source)
dataid_df = dataid_df[["easting", "northing", "dataid", "source"]]

# only keep points in ice shelf region
onshore_points= ptk.utils.points_inside_region(dataid_df, region)
onshore_points
# Out:
#           easting  northing  dataid     source
# 60450626 -1624000   -664000    10.0  multibeam
# 60450627 -1623500   -664000    10.0  multibeam
# 60450628 -1623000   -664000    10.0  multibeam
# 60450629 -1622500   -664000    10.0  multibeam
# 60450630 -1622000   -664000    10.0  multibeam
# ...           ...       ...     ...        ...
# 71990075 -1139500  -1214500     1.0       rema
# 72000554 -1140000  -1215000     1.0       rema
# 72000555 -1139500  -1215000     1.0       rema
# 72011033 -1140500  -1215500     1.0       rema
# 72011034 -1140000  -1215500     1.0       rema
#
# [65343 rows x 4 columns]

# %%
# get bedmap3 bed topography grid
bed_topography = ptk.fetch.bedmap3(layer="bed", region = region, reference="ellipsoid")

# show map of the points
fig = ptk.maps.plot_grd(bed_topography, coast=True)
fig.add_points(onshore_points, style="p.2p", fill="red")
fig.show()
# Out:
# requested spacing (500.0) is smaller than the original (1000.0).
# C:\Users\iii\AppData\Local\Temp\ipykernel_13352\2640832482.py:5: DeprecatedWarning: plot_grd is deprecated as of 1.3.1 and will be removed in 2.0.0. Use the new function `plot_grid()` instead
#   fig = ptk.maps.plot_grd(bed_topography, coast=True)
# C:\Users\iii\miniforge3\envs\invert4geom\Lib\site-packages\deprecation.py:260: UserWarning: `plot_grd` is deprecated, use `plot_grid` instead.
#   return function(*args, **kwargs)
# C:\Users\iii\miniforge3\envs\invert4geom\Lib\site-packages\polartoolkit\maps.py:3412: UserWarning: origin_shift 'initialize' is deprecated, use None instead.
#   fig.shift_figure(

# %% [markdown]
# # Get offshore points of known bathymetry

# %%
import pandas as pd
import geopandas as gpd
import shapely

def polygons_to_points(
    polygons: gpd.GeoDataFrame,
    spacing: float = 100,
) -> pd.DataFrame:
    """
    Convert a geodataframe of polygons to a grid of points with a specified spacing.

    Parameters
    ----------
    polygons : geopandas.GeoDataFrame
        Geodataframe of polygons to convert to points
    spacing : float, optional
        Spacing between points, by default 100

    Returns
    -------
    pd.DataFrame
        Dataframe of points with columns "easting", "northing", and "geometry"
    """
    points_list = []
    for _, row in polygons.iterrows():
        points_list.append(polygon_to_points(row, spacing=spacing))

    return pd.concat(points_list)


def polygon_to_points(
    polygon: gpd.GeoSeries,
    spacing: float = 100,
) -> pd.DataFrame:
    """
    Convert a polygon shapefile to a grid of points with a specified spacing. Also
    include the vertices of the polygon.

    Parameters
    ----------
    polygon : gpd.GeoSeries
        Polygon shapefile to convert to points
    spacing : float, optional
        Spacing between points, by default 100

    Returns
    -------
    pd.DataFrame
        Dataframe of points with columns "easting", "northing", and "geometry"
    """

    # get bounds of polygon
    bounds = polygon.geometry.bounds

    # create grid of points
    x_coords = np.arange(bounds[0], bounds[2], spacing)
    y_coords = np.arange(bounds[1], bounds[3], spacing)
    points = [shapely.geometry.Point(x, y) for x in x_coords for y in y_coords]

    # Filter points within the polygon
    points_in_polygon = [point for point in points if polygon.geometry.contains(point)]

    # add vertices of polygon
    points_in_polygon.extend(
        [shapely.geometry.Point(x, y) for (x, y) in polygon.geometry.exterior.coords]
    )

    # add points along edges
    points_in_polygon.extend(
        [
            shapely.geometry.Point(x, y)
            for (x, y) in polygon.geometry.segmentize(spacing).exterior.coords
        ]
    )

    # convert to geodataframe
    points_gdf = gpd.GeoDataFrame(geometry=points_in_polygon)

    # add easting and northing columns
    points_gdf["easting"] = [p.x for p in points_gdf.geometry]
    points_gdf["northing"] = [p.y for p in points_gdf.geometry]

    return points_gdf

# %%
# fetch IBCSO points for region
ibcso_points_gdf, ibcso_polygons_gdf = ptk.fetch.ibcso_coverage(region=region)

# drop points with TID of 45, meaning it's from gravity inversion
ibcso_points_gdf = ibcso_points_gdf[ibcso_points_gdf.dataset_tid != 45]

# convert polygons (mostly swath multibeam) to grid of points which are within the
# polygon with a grid spacing specified
polygon_points = None
if len(ibcso_polygons_gdf) > 0:
    try:
        polygon_points = polygons_to_points(
            ibcso_polygons_gdf,
            spacing=1e3,
        )
    except ValueError as e:
        print(e)
        print("Failed to convert polygons to points")

# combine IBCSO points and polygon points
offshore_points= pd.concat([ibcso_points_gdf, polygon_points])

# drop some columns
offshore_points= offshore_points.drop(columns=["geometry", "weight", "dataset_tid"])

offshore_points
# Out:
# ---------------------------------------------------------------------------
# CRSError                                  Traceback (most recent call last)
# Cell In[13], line 2
#       1 # fetch IBCSO points for region
# ----> 2 ibcso_points_gdf, ibcso_polygons_gdf = ptk.fetch.ibcso_coverage(region=region)
#       4 # drop points with TID of 45, meaning it's from gravity inversion
#       5 ibcso_points_gdf = ibcso_points_gdf[ibcso_points_gdf.dataset_tid != 45]
#
# File ~\miniforge3\envs\invert4geom\Lib\site-packages\polartoolkit\fetch.py:1760, in ibcso_coverage(region)
#    1758 # users supply region in EPSG:3031, but the data is in EPSG:9354
#    1759 reg_df = utils.region_to_df(region)
# -> 1760 region_epsg_9354 = utils.reproject(
#    1761     reg_df,
#    1762     input_crs="epsg:3031",
#    1763     output_crs="epsg:9354",
#    1764     reg=True,
#    1765     input_coord_names=("easting", "northing"),
#    1766     output_coord_names=("easting", "northing"),
#    1767 )
#    1768 bbox = utils.region_to_bounding_box(region_epsg_9354)  # type: ignore[arg-type]
#    1770 data = gpd.read_file(
#    1771     fname,
#    1772     bbox=bbox,
#    1773     use_arrow=USE_ARROW,
#    1774     engine="pyogrio",
#    1775 )
#
# File ~\miniforge3\envs\invert4geom\Lib\site-packages\polartoolkit\utils.py:769, in reproject(df, input_crs, output_crs, input_coord_names, output_coord_names, reg)
#     766 input_crs = input_crs.lower()
#     767 output_crs = output_crs.lower()
# --> 769 transformer = Transformer.from_crs(
#     770     input_crs,
#     771     output_crs,
#     772     always_xy=True,
#     773 )
#     775 if isinstance(df, pd.DataFrame):
#     776     df = df.copy()
#
# File ~\miniforge3\envs\invert4geom\Lib\site-packages\pyproj\transformer.py:626, in Transformer.from_crs(crs_from, crs_to, always_xy, area_of_interest, authority, accuracy, allow_ballpark, force_over, only_best)
#     551 @staticmethod
#     552 def from_crs(
#     553     crs_from: Any,
#    (...)    561     only_best: bool | None = None,
#     562 ) -> "Transformer":
#     563     """Make a Transformer from a :obj:`pyproj.crs.CRS` or input used to create one.
#     564
#     565     See:
#    (...)    622
#     623     """
#     624     return Transformer(
#     625         TransformerFromCRS(
# --> 626             cstrencode(CRS.from_user_input(crs_from).srs),
#     627             cstrencode(CRS.from_user_input(crs_to).srs),
#     628             always_xy=always_xy,
#     629             area_of_interest=area_of_interest,
#     630             authority=authority,
#     631             accuracy=accuracy if accuracy is None else str(accuracy),
#     632             allow_ballpark=allow_ballpark,
#     633             force_over=force_over,
#     634             only_best=only_best,
#     635         )
#     636     )
#
# File ~\miniforge3\envs\invert4geom\Lib\site-packages\pyproj\crs\crs.py:503, in CRS.from_user_input(cls, value, **kwargs)
#     501 if isinstance(value, cls):
#     502     return value
# --> 503 return cls(value, **kwargs)
#
# File ~\miniforge3\envs\invert4geom\Lib\site-packages\pyproj\crs\crs.py:350, in CRS.__init__(self, projparams, **kwargs)
#     348     self._local.crs = projparams
#     349 else:
# --> 350     self._local.crs = _CRS(self.srs)
#
# File ~\miniforge3\envs\invert4geom\Lib\site-packages\pyproj\_crs.pyx:2364, in pyproj._crs._CRS.__init__()
#
# CRSError: Invalid projection: epsg:3031: (Internal Proj Error: proj_create: no database context specified)

# %%
fig = maps.plot_grd(bed_topography, coast=True)
fig.add_points(offshore_points, style="p.2p", fill="red")
fig.show()

# %% [markdown]
# # Combine onshore and offshore points

# %%
constraint_points =  pd.concat(
    [offshore_points, onshore_points],
    ignore_index=True,
    sort=False,
)

# drop unnecessary columns
constraint_points = constraint_points.drop(columns=["dataset_name", "dataid", "source"])
constraint_points

# %%
fig = maps.plot_grd(bed_topography, coast=True)
fig.add_points(constraint_points, style="p.2p", fill="red")
fig.show()

# %% [markdown]
# # Block reduce

# %%
# block median with 1km blocks
reducer = vd.BlockReduce(reduction=np.median, spacing=1e3)
coordinates, data = reducer.filter(
    (constraint_points.easting, constraint_points.northing),
    np.ones_like(constraint_points.easting)
)

constraint_points = pd.DataFrame({"easting": coordinates[0], "northing": coordinates[1]})
constraint_points

# %%
''
# block median with 1km blocks
reducer = vd.BlockReduce(reduction=np.median, spacing=1e3)
coordinates, data = reducer.filter(
    (constraint_points.easting, constraint_points.northing),
    np.ones_like(constraint_points.easting)
)

constraint_points = pd.DataFrame({"easting": coordinates[0], "northing": coordinates[1]})
constraint_points
''

# %%
''
fig = maps.plot_grd(bed_topography, coast=True)
fig.add_points(constraint_points, style="p.2p", fill="red")
fig.show()
''

# %% [markdown]
# # Sample bed topography grid at these points

# %%
# sample bedrock topography at points
constraint_points = profiles.sample_grids(constraint_points, bed_topography, sampled_name="bed_elevation")

# drop points without bed elevation
constraint_points = constraint_points.dropna(subset=["bed_elevation"])
constraint_points

# %% [markdown]
# # Save to CSV

# %%
constraint_points.to_csv("constraint_points.csv", index=False)
