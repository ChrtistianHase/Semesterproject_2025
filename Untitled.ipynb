# %%
import polartoolkit
import verde as vd
import invert4geom
import numpy as np
import pandas as pd
import harmonica
import matplotlib.pyplot as plt

# %%
# %load_ext autoreload
# %autoreload 2
from polartoolkit import fetch, maps, profiles, regions

# %%
import os

os.environ["POLARTOOLKIT_HEMISPHERE"] = "south"

region = regions.getz_ice_shelf

# %% [markdown]
# # Point Data

# %%
bm_1 = fetch.bedmap_points(version='bedmap1',region = region)
bm_2 = fetch.bedmap_points(version='bedmap2',region = region)
bm_3 = fetch.bedmap_points(version='bedmap3',region = region)
# Out:
# C:\Users\iii\AppData\Local\Temp\ipykernel_8392\1155461425.py:1: UserWarning: Consider installing pyarrow for faster performance when reading geodataframes.
#   bm_1 = fetch.bedmap_points(version='bedmap1',region = region)
# C:\Users\iii\AppData\Local\Temp\ipykernel_8392\1155461425.py:2: UserWarning: Consider installing pyarrow for faster performance when reading geodataframes.
#   bm_2 = fetch.bedmap_points(version='bedmap2',region = region)
# C:\Users\iii\AppData\Local\Temp\ipykernel_8392\1155461425.py:3: UserWarning: Consider installing pyarrow for faster performance when reading geodataframes.
#   bm_3 = fetch.bedmap_points(version='bedmap3',region = region)

# %%
df = pd.DataFrame(bm_1)
df.to_csv('pointsmaps/bm1.csv')

df = pd.DataFrame(bm_2)
df.to_csv('pointsmaps/bm2.csv')

df = pd.DataFrame(bm_3)
df.to_csv('pointsmaps/bm3.csv')

# %%
bm1 = pd.read_csv('pointsmaps/bm1.csv')

bm2 = pd.read_csv('pointsmaps/bm2.csv')

bm3 = pd.read_csv('pointsmaps/bm3.csv')
# Out:
# C:\Users\iii\AppData\Local\Temp\ipykernel_3988\1383542050.py:3: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   bm2 = pd.read_csv('pointsmaps/bm2.csv')
# C:\Users\iii\AppData\Local\Temp\ipykernel_3988\1383542050.py:5: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   bm3 = pd.read_csv('pointsmaps/bm3.csv')

# %% [markdown]
# # Grids

# %%
ice_surface = fetch.bedmap3(layer="surface_topography", region = region)
ice_thickness = fetch.bedmap3(layer="ice_thickness", region = region)
bed_topography = fetch.bedmap3(layer="bed_topography", region = region)

# %%
gc = fetch.gravity(version = "antgg-2021", region = region,anomaly_type='FA')
# Out:
# ...
# 100%|#####################################| 28.5M/28.5M [00:00<00:00, 22.2GB/s]

# %%
fig1 =maps.plot_grd(ice_surface)
fig2 =maps.plot_grd(ice_thickness)
fig3 =maps.plot_grd(bed_topography)
#fig4 =maps.plot_grd(gc)

#fig = maps.subplots([fig1,fig2])
fig3.show(dpi=200)

# %% [markdown]
# # Starting topography

# %%
BM = pd.concat([bm1[['longitude (degree_east)','latitude (degree_north)','bedrock_altitude (m)']],
                bm2[['longitude (degree_east)','latitude (degree_north)','bedrock_altitude (m)']],
                bm3[['longitude (degree_east)','latitude (degree_north)','bedrock_altitude (m)']]])

#print(BM)

# %%
BM.plot.scatter(x='longitude (degree_east)',y= 'latitude (degree_north)', c='bedrock_altitude (m)',cmap= 'viridis')
#bm1.plot.scatter(x='longitude (degree_east)',y= 'latitude (degree_north)')
#bm2.plot.scatter(x='longitude (degree_east)',y= 'latitude (degree_north)')
#bm3.plot.scatter(x='longitude (degree_east)',y= 'latitude (degree_north)')

#uninterpolated data
# Out:
# <Axes: xlabel='longitude (degree_east)', ylabel='latitude (degree_north)'>

# %%
spacing=15/60

chain = vd.Chain(
    [
        ("mean", vd.BlockReduce(np.mean, spacing=spacing * 111e3)),
        ("spline", vd.Spline(damping=1e-10, mindist=100e3)),
    ]
)

# %%
chain.fit([BM['longitude (degree_east)'],BM['latitude (degree_north)']],BM['bedrock_altitude (m)'])
# Out:
# Chain(steps=[('mean',
#               BlockReduce(reduction=<function mean at 0x000002788EC4B3B0>,
#                           spacing=27750.0)),
#              ('spline', Spline(damping=1e-10, mindist=100000.0))])

# %%
grid_full = chain.grid(
    region=region,
    spacing=spacing,
    #projection=projection,
    dims=["latitude", "longitude"],
    data_names=["bed topography"],
)

## Mask points that are too far away from the original data points.
grid = vd.distance_mask(
    coordinates, maxdist=4 * spacing * 111e3, grid=grid_full, projection=projection
)
print(grid)


#I cant get grid to work
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 grid_full = chain.grid(
#       2     region=region,
#       3     spacing=spacing,
#       4     #projection=projection,
#       5     dims=["latitude", "longitude"],
#       6     data_names=["bed topography"],
#       7 )
#       9 ## Mask points that are too far away from the original data points.
#      10 grid = vd.distance_mask(
#      11     coordinates, maxdist=4 * spacing * 111e3, grid=grid_full, projection=projection
#      12 )
#
# File ~\anaconda3\envs\Semesterproject\Lib\site-packages\verde\base\base_classes.py:473, in BaseGridder.grid(self, region, shape, spacing, dims, data_names, projection, coordinates, **kwargs)
#     470 # Build the grid coordinates through vd.grid_coordinates
#     471 else:
#     472     region = get_instance_region(self, region)
# ...
